# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress, pearsonr
import csv

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1000)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1000)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 445

# %%
# print(cities)

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lng = []
Max_Temp = []
Wind_Speed = []

print("Retrieving Data")
print("-----------------")

x=0
# y=1
for city in cities:
    try:
        city_query_url = query_url + city
        x=x+1
        print(f"Retrieving Record {x} | {city}")
    #     print(city_query_url)
        data = requests.get(city_query_url).json()
    #     print(data)

        #assign temporary values
        cn = data["name"]
        cloud = data["clouds"]["all"]
        ctry = data["sys"]["country"]
        dt = data["dt"]
        hm = data["main"]["humidity"]
        lt = data["coord"]["lat"]
        ln = data["coord"]["lon"]
        mt = data["main"]["temp_max"]
        ws = data["wind"]["speed"]
    
    

        
        City.append(cn)
        Cloudiness.append(cloud)
        Country.append(ctry)
        Date.append(dt)
        Humidity.append(hm)
        Lat.append(lt)
        Lng.append(ln)
        Max_Temp.append(mt)
        Wind_Speed.append(ws)
        
    except KeyError:
        print(f"City not available... skip!")
        
print("-----------------")
print("Retrival Compete")
# Out:
# Retrieving Data
# -----------------
# Retrieving Record 1 | yenotayevka
# Retrieving Record 2 | wamba
# Retrieving Record 3 | tuatapere
# Retrieving Record 4 | ribeira grande
# Retrieving Record 5 | los llanos de aridane
# Retrieving Record 6 | avarua
# Retrieving Record 7 | vostok
# Retrieving Record 8 | tazovskiy
# Retrieving Record 9 | inhambane
# Retrieving Record 10 | gizo
# Retrieving Record 11 | rio grande
# Retrieving Record 12 | amazar
# Retrieving Record 13 | vaini
# Retrieving Record 14 | taolanaro
# City not available... skip!
# Retrieving Record 15 | caravelas
# Retrieving Record 16 | cheyenne
# Retrieving Record 17 | praya
# Retrieving Record 18 | lata
# Retrieving Record 19 | cape town
# Retrieving Record 20 | kodiak
# Retrieving Record 21 | goderich
# Retrieving Record 22 | barrow
# Retrieving Record 23 | provideniya
# Retrieving Record 24 | sao joao da barra
# Retrieving Record 25 | henties bay
# Retrieving Record 26 | angoram
# Retrieving Record 27 | albany
# Retrieving Record 28 | saleaula
# City not available... skip!
# Retrieving Record 29 | hermanus
# Retrieving Record 30 | atuona
# Retrieving Record 31 | george
# Retrieving Record 32 | mataura
# Retrieving Record 33 | saint anthony
# Retrieving Record 34 | moose factory
# Retrieving Record 35 | castro
# Retrieving Record 36 | sur
# Retrieving Record 37 | rawson
# Retrieving Record 38 | rikitea
# Retrieving Record 39 | tabas
# Retrieving Record 40 | chokurdakh
# Retrieving Record 41 | krasne
# Retrieving Record 42 | iqaluit
# Retrieving Record 43 | new norfolk
# Retrieving Record 44 | boundiali
# Retrieving Record 45 | amapa
# Retrieving Record 46 | qaanaaq
# Retrieving Record 47 | port alfred
# Retrieving Record 48 | coquimbo
# Retrieving Record 49 | hilo
# Retrieving Record 50 | kaitangata
# Retrieving Record 51 | puerto carreno
# Retrieving Record 52 | belushya guba
# City not available... skip!
# Retrieving Record 53 | abrau-dyurso
# Retrieving Record 54 | yellowknife
# Retrieving Record 55 | ahipara
# Retrieving Record 56 | mar del plata
# Retrieving Record 57 | punta arenas
# Retrieving Record 58 | constitucion
# Retrieving Record 59 | narsaq
# Retrieving Record 60 | mwingi
# Retrieving Record 61 | banihal
# Retrieving Record 62 | andenes
# Retrieving Record 63 | ushuaia
# Retrieving Record 64 | tehachapi
# Retrieving Record 65 | achisay
# City not available... skip!
# Retrieving Record 66 | bluff
# Retrieving Record 67 | mahdasht
# Retrieving Record 68 | butaritari
# Retrieving Record 69 | saint george
# Retrieving Record 70 | ballina
# Retrieving Record 71 | koungou
# Retrieving Record 72 | hithadhoo
# Retrieving Record 73 | vardo
# Retrieving Record 74 | tiznit
# Retrieving Record 75 | beringovskiy
# Retrieving Record 76 | deputatskiy
# Retrieving Record 77 | mwinilunga
# Retrieving Record 78 | acapulco
# Retrieving Record 79 | cayenne
# Retrieving Record 80 | norman wells
# Retrieving Record 81 | illoqqortoormiut
# City not available... skip!
# Retrieving Record 82 | jampang
# Retrieving Record 83 | novaya lyalya
# Retrieving Record 84 | busselton
# Retrieving Record 85 | bereda
# Retrieving Record 86 | bengkulu
# Retrieving Record 87 | pringsewu
# Retrieving Record 88 | cherskiy
# Retrieving Record 89 | codrington
# Retrieving Record 90 | praia
# Retrieving Record 91 | touros
# Retrieving Record 92 | antofagasta
# Retrieving Record 93 | nishihara
# Retrieving Record 94 | areka
# Retrieving Record 95 | tautira
# Retrieving Record 96 | machico
# Retrieving Record 97 | cabo san lucas
# Retrieving Record 98 | sao gabriel da cachoeira
# Retrieving Record 99 | lorena
# Retrieving Record 100 | pisco
# Retrieving Record 101 | nizhneyansk
# City not available... skip!
# Retrieving Record 102 | kizema
# Retrieving Record 103 | yibin
# Retrieving Record 104 | hualmay
# Retrieving Record 105 | avera
# Retrieving Record 106 | pangody
# Retrieving Record 107 | lebu
# Retrieving Record 108 | papasquiaro
# City not available... skip!
# Retrieving Record 109 | bredasdorp
# Retrieving Record 110 | tiksi
# Retrieving Record 111 | tuktoyaktuk
# Retrieving Record 112 | mahebourg
# Retrieving Record 113 | nadym
# Retrieving Record 114 | pacific grove
# Retrieving Record 115 | muriti
# Retrieving Record 116 | bethel
# Retrieving Record 117 | mamontovo
# Retrieving Record 118 | canyon lake
# Retrieving Record 119 | jamestown
# Retrieving Record 120 | port elizabeth
# Retrieving Record 121 | maningrida
# Retrieving Record 122 | suntar
# Retrieving Record 123 | ancud
# Retrieving Record 124 | adrar
# Retrieving Record 125 | nuuk
# Retrieving Record 126 | east london
# Retrieving Record 127 | amderma
# City not available... skip!
# Retrieving Record 128 | apiai
# Retrieving Record 129 | clyde river
# Retrieving Record 130 | san jose
# Retrieving Record 131 | lompoc
# Retrieving Record 132 | aswan
# Retrieving Record 133 | kavieng
# Retrieving Record 134 | salinopolis
# Retrieving Record 135 | katsuura
# Retrieving Record 136 | puerto ayora
# Retrieving Record 137 | hamilton
# Retrieving Record 138 | kalangala
# Retrieving Record 139 | mys shmidta
# City not available... skip!
# Retrieving Record 140 | gamba
# Retrieving Record 141 | qaqortoq
# Retrieving Record 142 | antigonish
# Retrieving Record 143 | burla
# Retrieving Record 144 | hambantota
# Retrieving Record 145 | san cristobal
# Retrieving Record 146 | kahului
# Retrieving Record 147 | sault sainte marie
# Retrieving Record 148 | belgrade
# Retrieving Record 149 | bardsir
# Retrieving Record 150 | esperance
# Retrieving Record 151 | padang
# Retrieving Record 152 | airai
# Retrieving Record 153 | penzance
# Retrieving Record 154 | swellendam
# Retrieving Record 155 | alexandria
# Retrieving Record 156 | leh
# Retrieving Record 157 | tumannyy
# City not available... skip!
# Retrieving Record 158 | jertih
# Retrieving Record 159 | nakamura
# Retrieving Record 160 | magistralnyy
# Retrieving Record 161 | sao filipe
# Retrieving Record 162 | cidreira
# Retrieving Record 163 | lydenburg
# Retrieving Record 164 | bhan
# Retrieving Record 165 | dikson
# Retrieving Record 166 | huangmei
# Retrieving Record 167 | nikolskoye
# Retrieving Record 168 | faya
# Retrieving Record 169 | saint-pierre
# Retrieving Record 170 | pevek
# Retrieving Record 171 | samusu
# City not available... skip!
# Retrieving Record 172 | charlestown
# Retrieving Record 173 | hobart
# Retrieving Record 174 | tsihombe
# City not available... skip!
# Retrieving Record 175 | luderitz
# Retrieving Record 176 | puerto baquerizo moreno
# Retrieving Record 177 | fort nelson
# Retrieving Record 178 | komsomolskiy
# Retrieving Record 179 | ust-nera
# Retrieving Record 180 | inuvik
# Retrieving Record 181 | santa fe
# Retrieving Record 182 | gornopravdinsk
# Retrieving Record 183 | marienburg
# Retrieving Record 184 | honningsvag
# Retrieving Record 185 | pak phanang
# Retrieving Record 186 | dorogino
# Retrieving Record 187 | flinders
# Retrieving Record 188 | babat
# Retrieving Record 189 | maxixe
# Retrieving Record 190 | palabuhanratu
# City not available... skip!
# Retrieving Record 191 | fortuna
# Retrieving Record 192 | grand river south east
# City not available... skip!
# Retrieving Record 193 | shingu
# Retrieving Record 194 | kalianget
# Retrieving Record 195 | north bend
# Retrieving Record 196 | toliary
# City not available... skip!
# Retrieving Record 197 | riyadh
# Retrieving Record 198 | labuhan
# Retrieving Record 199 | bambous virieux
# Retrieving Record 200 | kormilovka
# Retrieving Record 201 | victoria
# Retrieving Record 202 | thompson
# Retrieving Record 203 | kapaa
# Retrieving Record 204 | barra do bugres
# Retrieving Record 205 | arraial do cabo
# Retrieving Record 206 | kavaratti
# Retrieving Record 207 | husavik
# Retrieving Record 208 | saskylakh
# Retrieving Record 209 | petropavlovka
# Retrieving Record 210 | mogadishu
# Retrieving Record 211 | ulundi
# Retrieving Record 212 | salisbury
# Retrieving Record 213 | balkhash
# Retrieving Record 214 | okandja
# City not available... skip!
# Retrieving Record 215 | barentsburg
# City not available... skip!
# Retrieving Record 216 | saint-philippe
# Retrieving Record 217 | vao
# Retrieving Record 218 | seoul
# Retrieving Record 219 | dukat
# Retrieving Record 220 | dire
# Retrieving Record 221 | bucerias
# Retrieving Record 222 | mount isa
# Retrieving Record 223 | petropavlovsk-kamchatskiy
# Retrieving Record 224 | galveston
# Retrieving Record 225 | coihaique
# Retrieving Record 226 | hobyo
# Retrieving Record 227 | lavello
# Retrieving Record 228 | bonao
# Retrieving Record 229 | salalah
# Retrieving Record 230 | rochegda
# Retrieving Record 231 | havre-saint-pierre
# Retrieving Record 232 | geraldton
# Retrieving Record 233 | baherden
# Retrieving Record 234 | laguna
# Retrieving Record 235 | yulara
# Retrieving Record 236 | muisne
# Retrieving Record 237 | cabinda
# Retrieving Record 238 | beyneu
# Retrieving Record 239 | meulaboh
# Retrieving Record 240 | ituiutaba
# Retrieving Record 241 | sept-iles
# Retrieving Record 242 | kill
# Retrieving Record 243 | altamont
# Retrieving Record 244 | souillac
# Retrieving Record 245 | sikasso
# Retrieving Record 246 | tigil
# Retrieving Record 247 | isangel
# Retrieving Record 248 | kruisfontein
# Retrieving Record 249 | northam
# Retrieving Record 250 | nelson bay
# Retrieving Record 251 | nome
# Retrieving Record 252 | saldanha
# Retrieving Record 253 | campbell river
# Retrieving Record 254 | rungata
# City not available... skip!
# Retrieving Record 255 | naftah
# City not available... skip!
# Retrieving Record 256 | bedele
# Retrieving Record 257 | belle fourche
# Retrieving Record 258 | impfondo
# Retrieving Record 259 | mayumba
# Retrieving Record 260 | sevierville
# Retrieving Record 261 | axim
# Retrieving Record 262 | alotau
# City not available... skip!
# Retrieving Record 263 | lunenburg
# Retrieving Record 264 | verkh-usugli
# Retrieving Record 265 | carnarvon
# Retrieving Record 266 | fort wayne
# Retrieving Record 267 | washougal
# Retrieving Record 268 | palmer
# Retrieving Record 269 | longyearbyen
# Retrieving Record 270 | igis
# Retrieving Record 271 | tynda
# Retrieving Record 272 | alofi
# Retrieving Record 273 | lamu
# Retrieving Record 274 | ilulissat
# Retrieving Record 275 | alice springs
# Retrieving Record 276 | sentyabrskiy
# City not available... skip!
# Retrieving Record 277 | klaksvik
# Retrieving Record 278 | bima
# Retrieving Record 279 | yeniseysk
# Retrieving Record 280 | nemuro
# Retrieving Record 281 | grindavik
# Retrieving Record 282 | nicoya
# Retrieving Record 283 | torbay
# Retrieving Record 284 | georgetown
# Retrieving Record 285 | general roca
# Retrieving Record 286 | ko samui
# Retrieving Record 287 | port lincoln
# Retrieving Record 288 | porto novo
# Retrieving Record 289 | guerrero negro
# Retrieving Record 290 | zabid
# Retrieving Record 291 | poum
# Retrieving Record 292 | villa maria
# Retrieving Record 293 | comodoro rivadavia
# Retrieving Record 294 | gopalganj
# Retrieving Record 295 | malinovskiy
# Retrieving Record 296 | marcona
# City not available... skip!
# Retrieving Record 297 | wenling
# Retrieving Record 298 | bataipora
# Retrieving Record 299 | chicama
# Retrieving Record 300 | natal
# Retrieving Record 301 | mount gambier
# Retrieving Record 302 | tasiilaq
# Retrieving Record 303 | vestmannaeyjar
# Retrieving Record 304 | warrnambool
# Retrieving Record 305 | haines junction
# Retrieving Record 306 | the pas
# Retrieving Record 307 | brigantine
# Retrieving Record 308 | wanning
# Retrieving Record 309 | mapiri
# Retrieving Record 310 | juifang
# City not available... skip!
# Retrieving Record 311 | tabiauea
# City not available... skip!
# Retrieving Record 312 | zhezkazgan
# Retrieving Record 313 | khairpur
# Retrieving Record 314 | saint-augustin
# Retrieving Record 315 | kulhudhuffushi
# Retrieving Record 316 | abu dhabi
# Retrieving Record 317 | aklavik
# Retrieving Record 318 | malakal
# Retrieving Record 319 | ybbs
# City not available... skip!
# Retrieving Record 320 | angoche
# Retrieving Record 321 | port hedland
# Retrieving Record 322 | yar-sale
# Retrieving Record 323 | conceicao do araguaia
# Retrieving Record 324 | mangai
# Retrieving Record 325 | port moresby
# Retrieving Record 326 | moron
# Retrieving Record 327 | luganville
# Retrieving Record 328 | riberalta
# Retrieving Record 329 | dhidhdhoo
# Retrieving Record 330 | takoradi
# Retrieving Record 331 | bantogon
# Retrieving Record 332 | manyana
# Retrieving Record 333 | solovetskiy
# City not available... skip!
# Retrieving Record 334 | nova olimpia
# Retrieving Record 335 | tamasane
# Retrieving Record 336 | richards bay
# Retrieving Record 337 | bilma
# Retrieving Record 338 | rusape
# Retrieving Record 339 | ternate
# Retrieving Record 340 | lorengau
# Retrieving Record 341 | phan rang
# City not available... skip!
# Retrieving Record 342 | faanui
# Retrieving Record 343 | zhuravky
# Retrieving Record 344 | kanniyakumari
# Retrieving Record 345 | quballat
# Retrieving Record 346 | ponta do sol
# Retrieving Record 347 | tatarsk
# Retrieving Record 348 | kuminskiy
# Retrieving Record 349 | sitka
# Retrieving Record 350 | umea
# Retrieving Record 351 | tsiroanomandidy
# Retrieving Record 352 | ambon
# Retrieving Record 353 | hasaki
# Retrieving Record 354 | muravlenko
# Retrieving Record 355 | tombouctou
# Retrieving Record 356 | beisfjord
# Retrieving Record 357 | yatou
# Retrieving Record 358 | kedougou
# Retrieving Record 359 | vega de alatorre
# Retrieving Record 360 | tidore
# City not available... skip!
# Retrieving Record 361 | muroto
# Retrieving Record 362 | brezovica pri ljubljani
# Retrieving Record 363 | siminicea
# Retrieving Record 364 | gat
# Retrieving Record 365 | whitehorse
# Retrieving Record 366 | ondorhaan
# City not available... skip!
# Retrieving Record 367 | mangrol
# Retrieving Record 368 | tera
# Retrieving Record 369 | isoka
# Retrieving Record 370 | kijang
# Retrieving Record 371 | kindu
# Retrieving Record 372 | polewali
# Retrieving Record 373 | oreanda
# City not available... skip!
# Retrieving Record 374 | severo-kurilsk
# Retrieving Record 375 | alta floresta
# Retrieving Record 376 | itarema
# Retrieving Record 377 | loa janan
# Retrieving Record 378 | arona
# Retrieving Record 379 | ankang
# Retrieving Record 380 | san rafael
# Retrieving Record 381 | mao
# Retrieving Record 382 | lago da pedra
# Retrieving Record 383 | hami
# Retrieving Record 384 | ishigaki
# Retrieving Record 385 | svetlyy
# Retrieving Record 386 | torrington
# Retrieving Record 387 | bathsheba
# Retrieving Record 388 | kieta
# Retrieving Record 389 | champerico
# Retrieving Record 390 | chuy
# Retrieving Record 391 | guane
# Retrieving Record 392 | upernavik
# Retrieving Record 393 | turukhansk
# Retrieving Record 394 | turinskaya sloboda
# Retrieving Record 395 | buqayq
# City not available... skip!
# Retrieving Record 396 | ceuta
# Retrieving Record 397 | vung tau
# Retrieving Record 398 | shenjiamen
# Retrieving Record 399 | aljezur
# Retrieving Record 400 | kamenka
# Retrieving Record 401 | yanan
# City not available... skip!
# Retrieving Record 402 | bud
# Retrieving Record 403 | sechelt
# Retrieving Record 404 | huarmey
# Retrieving Record 405 | quebo
# Retrieving Record 406 | aktau
# Retrieving Record 407 | paamiut
# Retrieving Record 408 | san patricio
# Retrieving Record 409 | okha
# Retrieving Record 410 | rio gallegos
# Retrieving Record 411 | ahuimanu
# Retrieving Record 412 | half moon bay
# Retrieving Record 413 | tupiza
# Retrieving Record 414 | oriximina
# Retrieving Record 415 | artyk
# City not available... skip!
# Retrieving Record 416 | hofn
# Retrieving Record 417 | vila do maio
# Retrieving Record 418 | reconquista
# Retrieving Record 419 | veraval
# Retrieving Record 420 | mataiea
# City not available... skip!
# Retrieving Record 421 | jaguariaiva
# Retrieving Record 422 | genhe
# Retrieving Record 423 | vila velha
# Retrieving Record 424 | lavrentiya
# Retrieving Record 425 | mainit
# Retrieving Record 426 | caranavi
# Retrieving Record 427 | san vicente
# Retrieving Record 428 | samarai
# Retrieving Record 429 | giyani
# Retrieving Record 430 | viligili
# City not available... skip!
# Retrieving Record 431 | perisor
# City not available... skip!
# Retrieving Record 432 | sawtell
# Retrieving Record 433 | bandarbeyla
# Retrieving Record 434 | margate
# Retrieving Record 435 | romny
# Retrieving Record 436 | shurob
# Retrieving Record 437 | davila
# Retrieving Record 438 | honiara
# Retrieving Record 439 | invermere
# Retrieving Record 440 | kuche
# City not available... skip!
# Retrieving Record 441 | nkhata bay
# Retrieving Record 442 | moranbah
# Retrieving Record 443 | ruatoria
# City not available... skip!
# Retrieving Record 444 | barabinsk
# Retrieving Record 445 | aden
# -----------------
# Retrival Compete

# %%
#   name = data["name"]
#   print(name)
    

# query_params = {
#     "appid": weather_api_key,
#     "q": city,
#     "units": units
# }
# weather_response = requests.get(url, params=query_params)
# weather_json = weather_response.json() 
# print(Cloudiness)

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# base = {"City": [], "Cloudiness": [], "Country": [], "Date": [], "Humidity": [], "Lat": [],
#      "Lng": [], "Max Temp": [], "Wind Speed":[]}
# cities_df = pd.DataFrame(data=base)
# cities_df
weather_df = pd.DataFrame({"City": City, "Cloudiness": Cloudiness, "Country": Country, "Date": Date, "Humidity": Humidity, "Latitude":  Lat, "Longitude":  Lng, "Max Temp": Max_Temp, "Wind Speed": Wind_Speed})

weather_df["Date"] = pd.to_datetime(weather_df["Date"], unit = "s")

weather_df.to_csv("city_output.csv")

weather_df
# Out:
#                       City  Cloudiness Country                Date  Humidity  \
# 0              Yenotayevka         100      RU 2020-10-27 02:01:19        60
# 1                    Wamba          27      NG 2020-10-27 02:01:20        55
# 2                Tuatapere          50      NZ 2020-10-27 02:01:20        62
# 3           Ribeira Grande         100      PT 2020-10-27 01:59:55        91
# 4    Los Llanos de Aridane           0      ES 2020-10-27 02:01:20        64
# ..                     ...         ...     ...                 ...       ...
# 402              Invermere          76      CA 2020-10-27 02:02:10        74
# 403             Nkhata Bay          67      MW 2020-10-27 02:02:10        70
# 404               Moranbah         100      AU 2020-10-27 02:02:10        30
# 405              Barabinsk          97      RU 2020-10-27 02:02:10        81
# 406                   Aden           0      YE 2020-10-27 02:02:10        60
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 0       47.25      47.03     44.19        8.81
# 1        8.93       8.60     72.39        3.33
# 2      -46.13     167.68     57.99        5.99
# 3       38.52     -28.70     68.49       13.47
# 4       28.66     -17.92     69.80        9.17
# ..        ...        ...       ...         ...
# 402     50.52    -116.04     21.99        1.99
# 403    -11.61      34.29     73.98        4.29
# 404    -22.00     148.05     90.59       10.38
# 405     55.36      78.36     43.38       13.44
# 406     12.78      45.04     81.14       11.45
#
# [407 rows x 9 columns]

# %%
weather_df.describe()
# Out:
#        Cloudiness    Humidity    Latitude   Longitude    Max Temp  Wind Speed
# count  407.000000  407.000000  407.000000  407.000000  407.000000  407.000000
# mean    52.250614   73.405405   16.777862   14.981744   58.549484    7.578821
# std     40.485187   19.934258   34.471231   91.240469   21.265149    5.477621
# min      0.000000    1.000000  -54.800000 -175.200000   -2.000000    0.360000
# 25%      3.000000   63.000000  -12.400000  -63.960000   45.525000    3.360000
# 50%     58.000000   78.000000   18.800000   20.260000   64.400000    6.440000
# 75%     93.000000   88.000000   46.505000   90.075000   75.290000   10.290000
# max    100.000000  100.000000   78.220000  179.320000   95.230000   37.650000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
hum_100 = weather_df.loc[weather_df["Humidity"] >= 100]
hum_100
# Out:
#                 City  Cloudiness Country                Date  Humidity  \
# 28            George           0      ZA 2020-10-27 02:01:23       100
# 74           Cayenne          20      GF 2020-10-27 01:58:01       100
# 108           Bethel          90      US 2020-10-27 02:01:29       100
# 119            Apiaí          73      BR 2020-10-27 02:01:33       100
# 134       Hambantota          75      LK 2020-10-27 02:01:35       100
# 170          Malbork         100      PL 2020-10-27 01:59:11       100
# 184       Kormilovka          75      RU 2020-10-27 02:01:41       100
# 213  Havre-St-Pierre          90      CA 2020-10-27 02:01:44       100
# 223        Sept-Îles          90      CA 2020-10-27 02:00:11       100
# 235   Campbell River          90      CA 2020-10-27 01:58:39       100
# 247           Palmer          90      US 2020-10-27 02:01:48       100
# 260           Nicoya          75      CR 2020-10-27 02:01:49       100
# 322             Umeå          90      SE 2020-10-27 02:01:57       100
# 334        Siminicea          90      RO 2020-10-27 02:01:59       100
# 335       Kiryat Gat           0      IL 2020-10-27 02:01:59       100
# 369              Bud          90      US 2020-10-27 02:02:05       100
# 392      San Vicente          53      AR 2020-10-27 02:02:08       100
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 28     -33.96      22.46     60.80        6.93
# 74       4.93     -52.33     78.80        4.70
# 108     41.37     -73.41     54.00        0.60
# 119    -24.51     -48.84     61.81        1.97
# 134      6.12      81.12     78.80        2.24
# 170     54.04      19.03     51.01        8.95
# 184     55.00      74.10     42.80       13.42
# 213     50.23     -63.60     30.20        8.05
# 223     50.20     -66.38     30.99        6.93
# 235     50.02    -125.24     41.00        2.24
# 247     42.16     -72.33     51.01        5.82
# 260     10.15     -85.45     75.20        2.24
# 322     63.83      20.26     44.01        2.24
# 334     47.70      26.40     51.01        5.82
# 335     31.61      34.76     69.01        0.76
# 369     39.45     -86.18     44.01        5.26
# 392    -26.62     -54.13     60.71        3.09

# %%
#  Get the indices of cities that have humidity over 100%.

dropped = weather_df.drop(hum_100.index, inplace=False)
dropped
# Out:
#                       City  Cloudiness Country                Date  Humidity  \
# 0              Yenotayevka         100      RU 2020-10-27 02:01:19        60
# 1                    Wamba          27      NG 2020-10-27 02:01:20        55
# 2                Tuatapere          50      NZ 2020-10-27 02:01:20        62
# 3           Ribeira Grande         100      PT 2020-10-27 01:59:55        91
# 4    Los Llanos de Aridane           0      ES 2020-10-27 02:01:20        64
# ..                     ...         ...     ...                 ...       ...
# 402              Invermere          76      CA 2020-10-27 02:02:10        74
# 403             Nkhata Bay          67      MW 2020-10-27 02:02:10        70
# 404               Moranbah         100      AU 2020-10-27 02:02:10        30
# 405              Barabinsk          97      RU 2020-10-27 02:02:10        81
# 406                   Aden           0      YE 2020-10-27 02:02:10        60
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 0       47.25      47.03     44.19        8.81
# 1        8.93       8.60     72.39        3.33
# 2      -46.13     167.68     57.99        5.99
# 3       38.52     -28.70     68.49       13.47
# 4       28.66     -17.92     69.80        9.17
# ..        ...        ...       ...         ...
# 402     50.52    -116.04     21.99        1.99
# 403    -11.61      34.29     73.98        4.29
# 404    -22.00     148.05     90.59       10.38
# 405     55.36      78.36     43.38       13.44
# 406     12.78      45.04     81.14       11.45
#
# [390 rows x 9 columns]

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
x1 = weather_df["Latitude"]
y1 = weather_df["Max Temp"]
plt.scatter(x1, y1)

plt.title("Latitude vs. Max Temp.")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")
plt.savefig("lat_vs_maxtemp")

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
x2 = weather_df["Latitude"]
y2 = weather_df["Humidity"]
plt.scatter(x2, y2)

plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("lat_vs_humidity")

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
x3 = weather_df["Latitude"]
y3 = weather_df["Cloudiness"]
plt.scatter(x3, y3)

plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("lat_vs_cloudiness")

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
x4 = weather_df["Latitude"]
y4 = weather_df["Wind Speed"]
plt.scatter(x4, y4)

plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("lat_vs_windspeed")

# %% [markdown]
# ## Linear Regression

# %%
north_df = weather_df.loc[weather_df["Latitude"] > 0]
north_df
# Out:
#                       City  Cloudiness Country                Date  Humidity  \
# 0              Yenotayevka         100      RU 2020-10-27 02:01:19        60
# 1                    Wamba          27      NG 2020-10-27 02:01:20        55
# 3           Ribeira Grande         100      PT 2020-10-27 01:59:55        91
# 4    Los Llanos de Aridane           0      ES 2020-10-27 02:01:20        64
# 6                   Vostok          90      RU 2020-10-27 02:01:20        63
# ..                     ...         ...     ...                 ...       ...
# 399                 Shŭrob           0      TJ 2020-10-27 02:02:09        61
# 400                 Davila          75      PH 2020-10-27 02:02:09        74
# 402              Invermere          76      CA 2020-10-27 02:02:10        74
# 405              Barabinsk          97      RU 2020-10-27 02:02:10        81
# 406                   Aden           0      YE 2020-10-27 02:02:10        60
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 0       47.25      47.03     44.19        8.81
# 1        8.93       8.60     72.39        3.33
# 3       38.52     -28.70     68.49       13.47
# 4       28.66     -17.92     69.80        9.17
# 6       46.49     135.88     43.48        2.51
# ..        ...        ...       ...         ...
# 399     40.05      70.55     41.27        1.23
# 400     18.47     120.58     86.00        4.70
# 402     50.52    -116.04     21.99        1.99
# 405     55.36      78.36     43.38       13.44
# 406     12.78      45.04     81.14       11.45
#
# [256 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x5 = north_df["Latitude"]
y5 = north_df["Max Temp"]
plt.scatter(x5, y5)

plt.title("Latitude vs. Max Temp. (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

np.polyfit(x5, y5, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x5, y5)
slope, intercept

predict = x5*slope + intercept
predict

line_eq = f"y = {round(slope)}x + {round(intercept)}"
r_val = pearsonr(x5, y5)[0]
r_sq =  r_val ** 2

plt.plot(x5, predict, color="red")
plt.annotate(line_eq, (60, 70), color="red")
plt.annotate(f"R-squared: {round(r_sq, 4)}", (60,60), color="red")

plt.savefig("N_lat_vs_maxtemp")

# %%
south_df = weather_df.loc[weather_df["Latitude"] < 0]

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x6 = south_df["Latitude"]
y6 = south_df["Max Temp"]
plt.scatter(x6, y6)


plt.title("Latitude vs. Max Temp. (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Max Temp (F)")

np.polyfit(x6, y6, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x6, y6)
slope, intercept

s_mt_lat_predict = x6*slope + intercept

line_eq6 = f"y = {round(slope)}x + {round(intercept)}"
r_val6 = pearsonr(x6, y6)[0]
r_sq6 =  r_val6 ** 2

plt.plot(x6, s_mt_lat_predict, color="red")
plt.annotate(line_eq6, (-50, 90), color="red")
plt.annotate(f"R-squared: {round(r_sq6, 4)}", (-50, 85), color="red")

plt.savefig("S_lat_vs_maxtemp")

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x7 = north_df["Latitude"]
y7 = north_df["Humidity"]
plt.scatter(x7, y7)

plt.title("Latitude vs. Humidity (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

np.polyfit(x7, y7, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x7, y7)
slope, intercept

n_hum_lat_predict = x7*slope + intercept

line_eq7 = f"y = {round(slope)}x + {round(intercept)}"
r_val7 = pearsonr(x7, y7)[0]
r_sq7 =  r_val7 ** 2

plt.plot(x7, n_hum_lat_predict, color="red")
plt.annotate(line_eq7, (60, 20), color="red")
plt.annotate(f"R-squared: {round(r_sq7, 4)}", (60,10), color="red")

plt.savefig("N_lat_vs_humidity")

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x8 = south_df["Latitude"]
y8 = south_df["Humidity"]
plt.scatter(x8, y8)


plt.title("Latitude vs. Humidity (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

np.polyfit(x8, y8, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x8, y8)
slope, intercept

s_hum_lat_predict = x8*slope + intercept

line_eq8 = f"y = {round(slope)}x + {round(intercept)}"
r_val8 = pearsonr(x8, y8)[0]
r_sq8 =  r_val8 ** 2

plt.plot(x8, s_hum_lat_predict, color="red")
plt.annotate(line_eq8, (-50, 100), color="red")
plt.annotate(f"R-squared: {round(r_sq8, 4)}", (-50, 95), color="red")

plt.savefig("S_lat_vs_humidity")

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x9 = north_df["Latitude"]
y9 = north_df["Cloudiness"]
plt.scatter(x9, y9)

plt.title("Latitude vs. Cloudiness (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

np.polyfit(x9, y9, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x9, y9)
slope, intercept

n_cloud_lat_predict = x9*slope + intercept

line_eq9 = f"y = {round(slope)}x + {round(intercept)}"
r_val9 = pearsonr(x9, y9)[0]
r_sq9 =  r_val9 ** 2

plt.plot(x9, n_cloud_lat_predict, color="red")
plt.annotate(line_eq9, (60, 20), color="red")
plt.annotate(f"R-squared: {round(r_sq9, 4)}", (60,10), color="red")

plt.savefig("N_lat_vs_cloud")

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x10 = south_df["Latitude"]
y10 = south_df["Cloudiness"]
plt.scatter(x10, y10)


plt.title("Latitude vs. Cloudiness (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

np.polyfit(x10, y10, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x10, y10)
slope, intercept

s_cloud_lat_predict = x10*slope + intercept

line_eq10 = f"y = {round(slope)}x + {round(intercept)}"
r_val10 = pearsonr(x10, y10)[0]
r_sq10 =  r_val10 ** 2

plt.plot(x10, s_cloud_lat_predict, color="red")
plt.annotate(line_eq10, (-50, 60), color="red")
plt.annotate(f"R-squared: {round(r_sq10, 4)}", (-50, 55), color="red")

plt.savefig("S_lat_vs_cloud")

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x11 = north_df["Latitude"]
y11 = north_df["Wind Speed"]
plt.scatter(x11, y11)

plt.title("Latitude vs. Wind Speed (Northern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

np.polyfit(x11, y11, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x11, y11)
slope, intercept

n_ws_lat_predict = x11*slope + intercept

line_eq11 = f"y = {round(slope)}x + {round(intercept)}"
r_val11 = pearsonr(x11, y11)[0]
r_sq11 =  r_val11 ** 2

plt.plot(x11, n_ws_lat_predict, color="red")
plt.annotate(line_eq11, (55, 30), color="red")
plt.annotate(f"R-squared: {round(r_sq11, 4)}", (55,27), color="red")

plt.savefig("N_lat_vs_ws")

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x12 = south_df["Latitude"]
y12 = south_df["Wind Speed"]
plt.scatter(x12, y12)


plt.title("Latitude vs. Cloudiness (Southern Hemisphere)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

np.polyfit(x12, y12, 1)

(slope, intercept, rvalue, pvalue, stderr) = linregress(x12, y12)
slope, intercept

s_ws_lat_predict = x12*slope + intercept

line_eq12 = f"y = {round(slope)}x + {round(intercept)}"
r_val12 = pearsonr(x12, y12)[0]
r_sq12 =  r_val12 ** 2

plt.plot(x12, s_ws_lat_predict, color="red")
plt.annotate(line_eq12, (-20, 23), color="red")
plt.annotate(f"R-squared: {round(r_sq12, 4)}", (-20, 21), color="red")

plt.savefig("S_lat_vs_ws")
